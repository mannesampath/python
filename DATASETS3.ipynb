# %% [markdown]
# <a href="https://colab.research.google.com/github/mannesampath/python/blob/main/DATASETS3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/data/loan_data.csv")

# %%
# to view top rows
data.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
data.head(10)
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
# 5        21.0        female      High School        12951.0               0
# 6        26.0        female         Bachelor        93471.0               1
# 7        24.0        female      High School        95550.0               5
# 8        24.0        female        Associate       100684.0               3
# 9        21.0        female      High School        12739.0               0
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# ...

# %%
# to view bottom rows
data.tail()
# Out:
#        person_age person_gender person_education  person_income  \
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 44995               6                  RENT    15000.0            MEDICAL
# 44996              17                  RENT     9000.0    HOMEIMPROVEMENT
# 44997               7                  RENT     2771.0  DEBTCONSOLIDATION
# 44998               4                  RENT    12000.0          EDUCATION
# 44999               1                  RENT     6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# ...

# %%
data.tail(10)
# Out:
#        person_age person_gender person_education  person_income  \
# 44990        31.0          male           Master       136832.0
# 44991        24.0          male      High School        37786.0
# 44992        23.0        female         Bachelor        40925.0
# 44993        27.0        female      High School        35512.0
# 44994        24.0        female        Associate        31924.0
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 44990               9                  RENT    12319.0           PERSONAL
# 44991               0              MORTGAGE    13500.0          EDUCATION
# ...

# %%
#to find the no. of rows and columns
data.shape
# Out:
# (45000, 14)

# %%
#to know only rows
data.shape[0]
# Out:
# 45000

# %%
# to know only columns
data.shape[1]
# Out:
# 14

# %%
# To know the complete information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %%
# to find statistical description about numerical columns:
data.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %%
# location
data.iloc[5] #i = integer,loc = location
# Out:
# person_age                               21.0
# person_gender                          female
# person_education                  High School
# person_income                         12951.0
# person_emp_exp                              0
# person_home_ownership                     OWN
# loan_amnt                              2500.0
# loan_intent                           VENTURE
# loan_int_rate                            7.14
# loan_percent_income                      0.19
# cb_person_cred_hist_length                2.0
# credit_score                              532
# previous_loan_defaults_on_file             No
# loan_status                                 1
# Name: 5, dtype: object

# %%
data.iloc[0:5]
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
data.loc[2]
# Out:
# person_age                               25.0
# person_gender                          female
# person_education                  High School
# person_income                         12438.0
# person_emp_exp                              3
# person_home_ownership                MORTGAGE
# loan_amnt                              5500.0
# loan_intent                           MEDICAL
# loan_int_rate                           12.87
# loan_percent_income                      0.44
# cb_person_cred_hist_length                3.0
# credit_score                              635
# previous_loan_defaults_on_file             No
# loan_status                                 1
# Name: 2, dtype: object

# %%
data.loc[4:60]
# Out:
#     person_age person_gender person_education  person_income  person_emp_exp  \
# 4         24.0          male           Master        66135.0               1
# 5         21.0        female      High School        12951.0               0
# 6         26.0        female         Bachelor        93471.0               1
# 7         24.0        female      High School        95550.0               5
# 8         24.0        female        Associate       100684.0               3
# 9         21.0        female      High School        12739.0               0
# 10        22.0        female      High School       102985.0               0
# 11        21.0        female        Associate        13113.0               0
# 12        23.0          male         Bachelor       114860.0               3
# 13        26.0          male           Master       130713.0               0
# 14        23.0        female        Associate       138998.0               0
# ...

# %%
# check null values present or not

# %%
data.isna()
# Out:
#        person_age  person_gender  person_education  person_income  \
# 0           False          False             False          False
# 1           False          False             False          False
# 2           False          False             False          False
# 3           False          False             False          False
# 4           False          False             False          False
# ...           ...            ...               ...            ...
# 44995       False          False             False          False
# 44996       False          False             False          False
# 44997       False          False             False          False
# 44998       False          False             False          False
# 44999       False          False             False          False
#
#        person_emp_exp  person_home_ownership  loan_amnt  loan_intent  \
# 0               False                  False      False        False
# ...

# %%
#To know is there any null values or not
data.isna().any()
# Out:
# person_age                        False
# person_gender                     False
# person_education                  False
# person_income                     False
# person_emp_exp                    False
# person_home_ownership             False
# loan_amnt                         False
# loan_intent                       False
# loan_int_rate                     False
# loan_percent_income               False
# cb_person_cred_hist_length        False
# credit_score                      False
# previous_loan_defaults_on_file    False
# loan_status                       False
# dtype: bool

# %%
# to get the count of null values
data.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
# To access single column from a dataset

# %%
data["person_education"].head()
# Out:
# 0         Master
# 1    High School
# 2    High School
# 3       Bachelor
# 4         Master
# Name: person_education, dtype: object

# %%
#to access double column

# %%
data[["person_education","loan_amnt"]].head()
# Out:
#   person_education  loan_amnt
# 0           Master    35000.0
# 1      High School     1000.0
# 2      High School     5500.0
# 3         Bachelor    35000.0
# 4           Master    35000.0

# %%
data[["person_education","loan_amnt"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   person_education  45000 non-null  object
#  1   loan_amnt         45000 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 703.3+ KB

# %%
# filter

# %%
data[data["person_age"]>50].head()
# Out:
#        person_age person_gender person_education  person_income  \
# 81          144.0          male         Bachelor       300616.0
# 183         144.0          male        Associate       241424.0
# 575         123.0        female      High School        97140.0
# 747         123.0          male         Bachelor        94723.0
# 32297       144.0        female        Associate      7200766.0
#
#        person_emp_exp person_home_ownership  loan_amnt loan_intent  \
# 81                125                  RENT     4800.0     VENTURE
# 183               121              MORTGAGE     6000.0   EDUCATION
# 575               101                  RENT    20400.0   EDUCATION
# 747               100                  RENT    20000.0     VENTURE
# 32297             124              MORTGAGE     5000.0    PERSONAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 81             13.57                 0.02                         3.0
# ...

# %%
data[data["person_age"]<50].head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
data = pd.read_csv("/content/drive/MyDrive/data/loan_data.csv")

# %%
data1 = data[(data['person_gender']== 'female') & (data['person_education'] == 'Bachelor')]
print(data1)
# Out:
#        person_age person_gender person_education  person_income  \
# 3            23.0        female         Bachelor        79753.0
# 6            26.0        female         Bachelor        93471.0
# 23           24.0        female         Bachelor        13866.0
# 28           24.0        female         Bachelor        79054.0
# 29           21.0        female         Bachelor        14988.0
# ...           ...           ...              ...            ...
# 44967        28.0        female         Bachelor        34634.0
# 44968        30.0        female         Bachelor        62216.0
# 44970        26.0        female         Bachelor        84780.0
# 44975        23.0        female         Bachelor        58744.0
# 44992        23.0        female         Bachelor        40925.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 3                   0                  RENT    35000.0            MEDICAL
# ...

# %%
#stackoverflow we use to find the errors
