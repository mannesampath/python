# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# rename the column

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df = df.rename(columns={'sex':'gender'})
df.columns
# Out:
# Index(['survived', 'pclass', 'gender', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df = df.rename(columns={'sex':'gender','class':'class_name'})
df.columns
# Out:
# Index(['survived', 'pclass', 'gender', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class_name', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# identifiers outliers using IQR
import numpy as np

# %%
df['fare'].isna().sum()
# Out:
# 0

# %%
fare = df['fare'].dropna()

# %%
q1 = fare.quantile(0.25)

q3 = fare.quantile(0.75)

iqr = q3-q1
lower_bound = q1 - 1.5*iqr
upper_bound = q3 + 1.5*iqr
outliers = df[(df['fare']< lower_bound)|(df['fare']> upper_bound)]
print("Outliers",outliers[['fare']])
# Out:
# Outliers          fare
# 1     71.2833
# 27   263.0000
# 31   146.5208
# 34    82.1708
# 52    76.7292
# ..        ...
# 846   69.5500
# 849   89.1042
# 856  164.8667
# 863   69.5500
# 879   83.1583
#
# [116 rows x 1 columns]

# %%
# CREATING NEW COLUMNS IN EXISTING DATASET

# %%
df['age_category'] = df["age"].apply(lambda x:"senior" if x >= 60 else "adult" if x>=18 else "child")
print(df[['age','age_category']].head(10))
# Out:
#     age age_category
# 0  22.0        adult
# 1  38.0        adult
# 2  26.0        adult
# 3  35.0        adult
# 4  35.0        adult
# 5   NaN        child
# 6  54.0        adult
# 7   2.0        child
# 8  27.0        adult
# 9  14.0        child

# %%
#groupby and agrregation: simply data summarization by using aggregation function

# %%
df_groupby = df.groupby('gender').agg({'fare':['mean','min','max']})
df_groupby
# Out:
#              fare
#              mean   min       max
# gender
# female  44.479818  6.75  512.3292
# male    25.523893  0.00  512.3292

# %%
#pivoting data : summarizing in the form of tables

# %%
df_pivot = df.pivot_table(index='gender',columns = 'class_name',values = 'fare',aggfunc = 'mean')
df_pivot
# Out:
# <ipython-input-146-5186d171bd1a>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df_pivot = df.pivot_table(index='gender',columns = 'class_name',values = 'fare',aggfunc = 'mean')
# class_name       First     Second      Third
# gender
# female      106.125798  21.970121  16.118810
# male         67.226127  19.741782  12.661633

# %%
# merging two dataframes:

# %%
df1 = sns.load_dataset('titanic')
df2 = sns.load_dataset('tips')
merged_df=pd.merge(df1,df2,on ='sex')
print(merged_df.head())
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone, total_bill, tip, smoker, day, time, size]
# Index: []
#
# [0 rows x 21 columns]

# %%
# filling the null values by using mean or median

# %%
df1 = sns.load_dataset('titanic')

# %%
df.head(5)
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked class_name  \
# 0         0       3    male  22.0      1      0   7.2500        S      Third
# 1         1       1  female  38.0      1      0  71.2833        C      First
# 2         1       3  female  26.0      0      0   7.9250        S      Third
# 3         1       1  female  35.0      1      0  53.1000        S      First
# 4         0       3    male  35.0      0      0   8.0500        S      Third
#
#      who  adult_male deck  embark_town alive  alone age_category
# 0    man        True  NaN  Southampton    no  False        adult
# 1  woman       False    C    Cherbourg   yes  False        adult
# 2  woman       False  NaN  Southampton   yes   True        adult
# 3  woman       False    C  Southampton   yes  False        adult
# 4    man        True  NaN  Southampton    no   True        adult

# %%
df1.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1['age'].fillna(df1['age'].mean(),inplace = True)
# Out:
# <ipython-input-147-762517c3d171>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['age'].fillna(df1['age'].mean(),inplace = True)

# %%
df1.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# where conditional cleaning(where function we use for cleaning th data)

# %%
df['fare_category']=np.where(df['fare']>50,'High','Low')
df.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked class_name  \
# 0         0       3    male  22.0      1      0   7.2500        S      Third
# 1         1       1  female  38.0      1      0  71.2833        C      First
# 2         1       3  female  26.0      0      0   7.9250        S      Third
# 3         1       1  female  35.0      1      0  53.1000        S      First
# 4         0       3    male  35.0      0      0   8.0500        S      Third
#
#      who  adult_male deck  embark_town alive  alone age_category fare_category
# 0    man        True  NaN  Southampton    no  False        adult           Low
# 1  woman       False    C    Cherbourg   yes  False        adult          High
# 2  woman       False  NaN  Southampton   yes   True        adult           Low
# 3  woman       False    C  Southampton   yes  False        adult          High
# 4    man        True  NaN  Southampton    no   True        adult           Low
